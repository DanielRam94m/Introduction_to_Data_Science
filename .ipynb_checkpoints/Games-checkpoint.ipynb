# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
df = pd.read_csv("vgsales.csv")

# %%
df.head(3)
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 2     3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82

# %%
df[["Publisher", "Name", "Genre"]]
# Out:
#         Publisher                                              Name  \
# 0        Nintendo                                        Wii Sports
# 1        Nintendo                                 Super Mario Bros.
# 2        Nintendo                                    Mario Kart Wii
# 3        Nintendo                                 Wii Sports Resort
# 4        Nintendo                          Pokemon Red/Pokemon Blue
# ...           ...                                               ...
# 16593       Kemco                Woody Woodpecker in Crazy Castle 5
# 16594  Infogrames                     Men in Black II: Alien Escape
# 16595  Activision  SCORE International Baja 1000: The Official Game
# 16596    7G//AMES                                        Know How 2
# 16597     Wanadoo                                  Spirits & Spells
#
#               Genre
# 0            Sports
# 1          Platform
# 2            Racing
# 3            Sports
# 4      Role-Playing
# ...             ...
# ...

# %%
df["Publisher"].value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# WayForward Technologies            1
# Playmates                          1
# Piacci                             1
# Origin Systems                     1
# Grand Prix Games                   1
# Name: Publisher, Length: 578, dtype: int64

# %%
pd.set_option("display.max_rows", None)
df["Publisher"].value_counts()
# Out:
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Disney Interactive Studios                 218
# Unknown                                    203
# Midway Games                               198
# Eidos Interactive                          198
# 505 Games                                  192
# ...

# %% [markdown]
# #### Create a file

# %%
df.to_excel("fileExported.xlsx")

# %%
df.loc[df["Publisher"] == "Square"]
# Out:
#         Rank                             Name Platform    Year         Genre  \
# 983      985                 Final Fantasy II     SNES  1991.0  Role-Playing
# 3226    3228  Final Fantasy VII International       PS  1997.0  Role-Playing
# 3833    3835         Final Fantasy Chronicles       PS  2001.0  Role-Playing
# 4383    4385         Final Fantasy Collection       PS  1999.0  Role-Playing
# 8642    8644                    Racing Lagoon       PS  1999.0        Racing
# 10309  10311             Final Fantasy I & II      NES  1994.0  Role-Playing
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 983      Square      0.24      0.09      1.33         0.12          1.77
# 3226     Square      0.00      0.00      0.59         0.04          0.63
# 3833     Square      0.29      0.20      0.00         0.03          0.52
# 4383     Square      0.00      0.00      0.42         0.03          0.45
# ...

# %%
df.loc[(df["Publisher"] == "Square") & (df["NA_Sales"] > 0)]
# Out:
#       Rank                      Name Platform    Year         Genre Publisher  \
# 983    985          Final Fantasy II     SNES  1991.0  Role-Playing    Square
# 3833  3835  Final Fantasy Chronicles       PS  2001.0  Role-Playing    Square
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 983       0.24      0.09      1.33         0.12          1.77
# 3833      0.29      0.20      0.00         0.03          0.52

# %% [markdown]
# #### Show nintendo games with NA sales greater than 10 and export it to excel

# %%
df.loc[(df["Publisher"] == "Nintendo") & (df["NA_Sales"] > 10)].to_excel("NintendoSalesGreaterThan10InNA.xlsx")

# %%
df.groupby(["Genre"]).mean()
# Out:
#                       Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Action         7973.879071  2007.909929  0.264726  0.158323  0.048236
# Adventure     11532.787714  2008.130878  0.082271  0.049868  0.040490
# Fighting       7646.511792  2004.630383  0.263667  0.119481  0.103007
# Misc           8561.847039  2007.258480  0.235906  0.124198  0.061967
# Platform       6927.251693  2003.820776  0.504571  0.227573  0.147596
# Puzzle         9627.381443  2005.243433  0.212680  0.087251  0.098471
# Racing         7961.515612  2004.840131  0.287766  0.190865  0.045388
# Role-Playing   8086.174731  2007.055744  0.219946  0.126384  0.236767
# Shooter        7369.367939  2005.918877  0.444733  0.239137  0.029221
# Simulation     8626.085352  2006.567568  0.211430  0.130773  0.073472
# Sports         7425.026428  2005.477865  0.291283  0.160635  0.057702
# Strategy      10071.897210  2005.599106  0.100881  0.066579  0.072628
#
#               Other_Sales  Global_Sales
# Genre
# ...

# %% [markdown]
# #### Printing Mean of an specific //without resizing

# %%
saleMeans = df.groupby(["Genre"]).mean()
plt.plot(saleMeans["NA_Sales"])

# %% [markdown]
# #### Chart Resizing & Exporting it as an image

# %%
saleMeans = df.groupby(["Genre"]).mean()
plt.figure(figsize=(12, 6))
plt.plot(saleMeans["NA_Sales"])

plt.savefig("Sales_na.jpg")

# %% [markdown]
# #### Show two different averages in contrast

# %%
meanComparison = df.groupby(['Genre']).mean()
plt.figure(figsize=(12,6))

sales_na = meanComparison['NA_Sales']
sales_eu = meanComparison['EU_Sales']

plt.plot(sales_na, color="red")
plt.plot(sales_eu, color="purple")
